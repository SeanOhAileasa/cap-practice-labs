# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/cap-practice-labs/blob/main/README.md) | [Threat Intelligence and Organizational Security](https://nbviewer.org/github/SeanOhAileasa/cap-threat-and-vulnerability-management/blob/main/rc/cap-threat-intelligence-and-organizational-security.ipynb) >
#
# ## CompTIA Cybersecurity Analyst (CySA+) Practice Labs
# ###### Topic: ``Threat Research``
# ***

# %% [markdown]
# Course material for the ``CompTIA Cybersecurity Analyst (CySA+)`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Lab Configuration](#LabTopology)

# %% [markdown]
# ### [Threat Research](#aa)

# %% [markdown]
# - [Indicators of Compromise - IoC](#1) <br/><br/>
# - [Common Vulnerability Scoring System - CVSS](#2)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="LabTopology"></a>
# ***
# ###### Lab Configuration
# ***

# %% [markdown]
# - PLABDC01 - (Windows Server 2019 - Domain Server)
# - PLABDM01 - (Windows Server 2019 - Domain Member)
# - PLABKALI01 - (Kali Linux 2019 - Linux Kali)
# - PLABWIN10 - (Windows 10 - Domain Member Workstation)
# - PLABCENTOS - (Centos 8 Linux - Stand-alone Linux Server)
# - PLABALIENVAULT - (Alien Vault Linux Security Management Platform)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="aa"></a>
# ***
# ### Threat Research
# ***

# %% [markdown]
# Assume a scenario in which a malware attack has taken place on a file server. After the attack has been determined, you have found traces of the malware in the log files, which contain events related to malware.
#
# It is then your responsibility to research said threats for possible remediation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="1"></a>
# ***
# ###### Indicators of Compromise - IoC
# ***

# %% [markdown]
# These events are considered to be the ``Indicators of Compromise`` (``IoC``). They are also used for forensics purposes, where investigators can determine activities performed by malware (or any other type of attack).
#
# Several recent versions of antimalware applications have the capability of using ``IoC`` - can also be used to determine breaches or any other types of security threats within the system.
#
# With the help of ``IoC``, threat researchers can determine the behavior of specific malware and it’s working methodology.
#
# Such information can then be shared with other organizations in the form of threat intelligence, which can help in improving the threat response and remediation methods.

# %% [markdown]
# ``IoC`` can be of various types:
#
#
# - Unusual network traffic, either inbound or outbound
#
#
# - Unusual activities performed by an administrative or privileged user account
#
#
# - Unusual changes in the operating system or registry
#
#
# - Unusual connections established
#
#
# - Unusual DNS modifications and requests
#
#
# - Untimely system patching

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="2"></a>
# ***
# ######  Common Vulnerability Scoring System - CVSS
# ***

# %% [markdown]
# When you find several vulnerabilities within an infrastructure, you would probably not know how to rank them or assign scores to them.
#
# ``CVSS`` helps you assign a score to each vulnerability, for example, you may have a vulnerability that is a risk to the confidentiality, integrity, and availability of your data.
#
# Using ``CVSS``, you can determine the score of such.
#
# Scores are calculated based on several metrics. Once you define these metrics, you would be able to determine the ``CVSS`` score of a vulnerability.
#
# A score of 10 to a vulnerability would make it severe - can also use ``CVSS`` calculators that can help you calculate the scores.

# %% [markdown]
# > Connect to ``PLABWIN10`` and open ``Microsoft Edge`` an navigate to:
#
# - ``https://www.first.org/cvss/calculator/3.1``

# %% [markdown]
# > Section ``Base Score``, selecting the following metrics:

# %% [markdown]
# Notice that the score is automatically calculated as $7.5$, which is considered to be ``High``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > Changing the following values:

# %% [markdown]
# The score is automatically calculated to $5.0$, which is considered to be ``Medium``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CompTIA Cybersecurity Analyst (CySA+) Practice Labs

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\SeanOhAileasa\AppData\Local\Temp\ipykernel_3036\1322614208.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display,HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
